# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
df=pd.read_csv("C:/Users/Admin/Guvi Mini Project/Amazon delivery price predection/Processed_data")

# %%
df.head()
# Out:
#    Unnamed: 0  Agent_Age  Agent_Rating     Weather Traffic      Vehicle  \
# 0           0         37           4.9       Sunny   High   motorcycle
# 1           1         34           4.5      Stormy    Jam      scooter
# 2           2         23           4.4  Sandstorms    Low   motorcycle
# 3           4         32           4.6      Cloudy   High      scooter
# 4           5         22           4.8      Cloudy    Jam   motorcycle
#
#              Area  Delivery_Time     Category  Distance_km  Pickup_Delay  \
# 0          Urban             120     Clothing     3.020737          15.0
# 1  Metropolitian             165  Electronics    20.143737           5.0
# 2          Urban             130       Sports     1.549693          15.0
# 3  Metropolitian             150         Toys     6.197898          15.0
# 4          Urban             130         Toys     4.602205          10.0
#
#    Order_Month  Order_Day Order_Weekday
# 0            3         19      Saturday
# ...

# %%
#scatterplot for distance vs delivery time
sns.scatterplot(data=df, x='Distance_km', y='Delivery_Time', hue='Category')
# Out:
# <Axes: xlabel='Distance_km', ylabel='Delivery_Time'>

# %%
#heatmap for agent_rating and delivery time
correlation = df[['Agent_Rating', 'Delivery_Time']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
# agent performance accorss various conditions
sns.lineplot(data=df, x='Weather', y='Agent_Rating')
# Out:
# <Axes: xlabel='Weather', ylabel='Agent_Rating'>

# %%
#impact of weather and traffic on delivery times
sns.scatterplot(data=df, x='Weather', y='Delivery_Time', hue='Traffic')
# Out:
# <Axes: xlabel='Weather', ylabel='Delivery_Time'>

# %%
#Distribution of delivery time
sns.lineplot(data=df, x='Distance_km', y='Delivery_Time')
# Out:
# <Axes: xlabel='Distance_km', ylabel='Delivery_Time'>

# %%
#delivery time for product category
sns.barplot(data=df, y='Category', x='Delivery_Time')
# Out:
# <Axes: xlabel='Delivery_Time', ylabel='Category'>
